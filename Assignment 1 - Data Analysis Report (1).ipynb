# %% [markdown]
# ## Radical X Squad Matching Algorithm

# %% [markdown]
# ### Objectives
#
# ### The dataset shall be cleaned through the following processes
#
# ### 1. Checking the number of colums
# ### 2. Checking misplet column names to correct names
# ### 3. Checking for missing values
# ### 4. Checking for duplicate values
# ### 5. Checking for outliers

# %% [markdown]
# ### importing required libraries and importing the dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns

df=pd.read_csv('Squad Matching data.csv')

# %% [markdown]
# ### Data Audit

# %%
df.head() # Analyze the first 5 rows
# Out:
#       Name  Squad Number Do you have any preferred language of communication?  \
# 0  Grayson           NaN  i prefer english but i am also able to communi...
# 1    Jonas           NaN                                            English
# 2    Ronan           NaN               English and Spanish are good for me.
# 3    Dulce           NaN                                            spanish
# 4   Evelyn           NaN                                            Spanish
#
#   What Group Virtual Internship Program are you interested in registering for  \
# 0                  Product Marketing,Product Growth
# 1   Product Marketing,Product Growth ,Product Design
# 2                                     Product Design
# 3                                     Product Design
# 4                                  Product Marketing
#
#     Age                     City Country 1    Country    Region  \
# 0  23.0       bordj bou arreridj       NaN    Algeria      MENA
# ...

# %%
df.tail() # last five rows of the dataset
# Out:
#            Name  Squad Number  \
# 1183  Johnathan           NaN
# 1184     Adriel           NaN
# 1185      Reyna           NaN
# 1186      Uriel           NaN
# 1187    Esteban           NaN
#
#      Do you have any preferred language of communication?  \
# 1183                                            English
# 1184  English is the language I am most comfortable ...
# 1185                                            English
# 1186                                            English
# 1187                                         Vietnamese
#
#      What Group Virtual Internship Program are you interested in registering for  \
# 1183                Product Development,Product Growth
# 1184                                Product Development
# 1185                                     Product Design
# 1186   Product Marketing,Product Design,Product Growth
# 1187                                Product Development
#
#        Age                    City Country 1    Country    Region  \
# ...

# %%
df.shape # find the role and column of the dataset
# Out:
# (1188, 85)

# %%
df.columns # Columns present in the dataset
# Out:
# Index(['Name', 'Squad Number',
#        'Do you have any preferred language of communication?',
#        'What Group Virtual Internship Program are you interested in registering for',
#        'Age', 'City', 'Country 1', 'Country', 'Region', 'Time Zone',
#        'current occupation?', 'School/University',
#        'What did you study at University/College?',
#        'Upskilling courses on online platforms like Udemy, Coursera, edX, or others?',
#        'Please describe what courses you have taken, if any.',
#        'Do you have any previous work or internship experience?',
#        'What is your preferred method of communication?', 'Product Management',
#        'Project Management', 'Digital Marketing', 'SEO/SEM', 'Paid Marketing',
#        'Influencer Marketing', 'Content Marketing', 'Email Marketing',
#        'Market Research', 'Graphic Design', 'Digital Illustration',
#        'Animation', 'Video Editing', 'Digital Content Creation', 'UX Design',
# ...

# %%
df.info() # A concise summary of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1188 entries, 0 to 1187
# Data columns (total 85 columns):
#  #   Column                                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                                         --------------  -----
#  0   Name                                                                                                                                           1188 non-null   object
#  1   Squad Number                                                                                                                                   0 non-null      float64
#  2   Do you have any preferred language of communication?                                                                                           1169 non-null   object
# ...

# %%
df.describe() #Display all the relevant stats information of the dataset
# Out:
#        Squad Number          Age  Product Management  Project Management  \
# count           0.0  1188.000000         1187.000000         1187.000000
# mean            NaN    23.946810            2.437237            2.684078
# std             NaN     4.512837            1.330050            1.379362
# min             NaN    16.000000            1.000000            1.000000
# 25%             NaN    21.000000            1.000000            1.000000
# 50%             NaN    23.000000            2.000000            3.000000
# 75%             NaN    26.000000            3.000000            4.000000
# max             NaN    54.000000            5.000000            5.000000
#
#        Digital Marketing     SEO/SEM  Paid Marketing  Influencer Marketing  \
# count         479.000000  595.000000       479.00000            479.000000
# mean            3.035491    2.129412         2.42380              2.398747
# std             1.408579    1.245217         1.37747              1.369756
# ...

# %%
df.nunique() # all the unique values in the dataset
# Out:
# Name                                                                        1188
# Squad Number                                                                   0
# Preferred Language                                                           256
# Virtual Internship Group Category                                             51
# Age                                                                           31
#                                                                             ...
# Please specify your starting date for the Product Marketing Internship         9
# Please specify your starting date for the Product Design Internship           13
# Please specify your starting date for the Product Development Internship       3
# Please specify your starting date for the Product Growth Internship            3
# Please indicate the number of hours per week on the Internship Program         3
# Length: 84, dtype: int64

# %%
df.isnull().sum() # checking missing values
# Out:
# Name                                                                               0
# Squad Number                                                                    1188
# Do you have any preferred language of communication?                              19
# What Group Virtual Internship Program are you interested in registering for        1
# Age                                                                                0
#                                                                                 ...
# Which cohorts are you available to start the Product Marketing Internship?       716
# Which cohorts are you available to start the Product Design Internship?          587
# Which cohorts are you available to start the Product Development Internship?     662
# Which cohorts are you available to start the Product Growth Internship?          889
# How many hours per week are you able to give to the internship program?            0
# Length: 85, dtype: int64

# %% [markdown]
# ### Data cleaning process

# %%
df.rename(columns={'Do you have any preferred language of communication?':'preferred_language_of_communication'},inplace=True)
df
# Out:
#            Name  Squad Number  \
# 0       Grayson           NaN
# 1         Jonas           NaN
# 2         Ronan           NaN
# 3         Dulce           NaN
# 4        Evelyn           NaN
# ...         ...           ...
# 1183  Johnathan           NaN
# 1184     Adriel           NaN
# 1185      Reyna           NaN
# 1186      Uriel           NaN
# 1187    Esteban           NaN
#
#                     preferred_language_of_communication  \
# 0     i prefer english but i am also able to communi...
# 1                                               English
# 2                  English and Spanish are good for me.
# 3                                               spanish
# 4                                               Spanish
# ...                                                 ...
# 1183                                            English
# 1184  English is the language I am most comfortable ...
# 1185                                            English
# ...

# %%
df.describe() #Display all the stats of the dataset
# Out:
#        Squad Number          Age  Product Management  Project Management  \
# count           0.0  1188.000000         1187.000000         1187.000000
# mean            NaN    23.946810            2.437237            2.684078
# std             NaN     4.512837            1.330050            1.379362
# min             NaN    16.000000            1.000000            1.000000
# 25%             NaN    21.000000            1.000000            1.000000
# 50%             NaN    23.000000            2.000000            3.000000
# 75%             NaN    26.000000            3.000000            4.000000
# max             NaN    54.000000            5.000000            5.000000
#
#        Digital Marketing     SEO/SEM  Paid Marketing  Influencer Marketing  \
# count         479.000000  595.000000       479.00000            479.000000
# mean            3.035491    2.129412         2.42380              2.398747
# std             1.408579    1.245217         1.37747              1.369756
# ...

# %%
# Out:
# Name                                                                             object
# Squad Number                                                                    float64
# Do you have any preferred language of communication?                             object
# What Group Virtual Internship Program are you interested in registering for      object
# Age                                                                             float64
#                                                                                  ...
# Which cohorts are you available to start the Product Marketing Internship?       object
# Which cohorts are you available to start the Product Design Internship?          object
# Which cohorts are you available to start the Product Development Internship?     object
# Which cohorts are you available to start the Product Growth Internship?          object
# How many hours per week are you able to give to the internship program?          object
# ...

# %%
# Lists all the missing/NA values in boolean form as 'True'
df.isna()
# Out:
#        Name  Squad Number  \
# 0     False          True
# 1     False          True
# 2     False          True
# 3     False          True
# 4     False          True
# ...     ...           ...
# 1183  False          True
# 1184  False          True
# 1185  False          True
# 1186  False          True
# 1187  False          True
#
#       Do you have any preferred language of communication?  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 1183                                              False
# 1184                                              False
# 1185                                              False
# 1186                                              False
# ...

# %%
# Replace NA (missing values) using Replace method

import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Squad Matching data.csv')

df.replace('NA',np.nan, inplace = True)

df.replace('Missing',np.nan, inplace = True)

# %%
df
# Out:
#          Name  Squad Number  \
# 1111   Holden           NaN
# 46    Katelyn           NaN
# 78     Cooper           NaN
# 524      Mila           NaN
# 1152   Joshua           NaN
# ...       ...           ...
# 427     Belen           NaN
# 296     Jerry           NaN
# 152     Atlas           NaN
# 1116   Sophie           NaN
# 452     Ariel           NaN
#
#      Do you have any preferred language of communication?  \
# 1111                                            English
# 46                                              English
# 78                                              English
# 524                                             English
# 1152                                            English
# ...                                                 ...
# 427                                                  No
# 296                                             English
# 152                                             English
# ...

# %%
# remove missing values

df.dropna()
# Out:
# Empty DataFrame
# ...

# %%
# Apply the apply method to calculate the lenght of the dataset
df.apply(len)
# Out:
# Name                                                                        1188
# Squad Number                                                                1188
# Preferred Language                                                          1188
# Virtual Internship Group Category                                           1188
# Age                                                                         1188
#                                                                             ...
# Please specify your starting date for the Product Marketing Internship      1188
# Please specify your starting date for the Product Design Internship         1188
# Please specify your starting date for the Product Development Internship    1188
# Please specify your starting date for the Product Growth Internship         1188
# Please indicate the number of hours per week on the Internship Program      1188
# Length: 84, dtype: int64

# %%
# Calculate the number of columns in the df

df.apply(len, axis='columns')
# Out:
# 46      84
# 78      84
# 1152    84
# 524     84
# 1111    84
#         ..
# 427     84
# 296     84
# 152     84
# 1116    84
# 452     84
# Length: 1188, dtype: int64

# %%
# Calculate the number of rows in the df

df.apply(len, axis='rows')
# Out:
# Name                                                                        1188
# Squad Number                                                                1188
# Preferred Language                                                          1188
# Virtual Internship Group Category                                           1188
# Age                                                                         1188
#                                                                             ...
# Please specify your starting date for the Product Marketing Internship      1188
# Please specify your starting date for the Product Design Internship         1188
# Please specify your starting date for the Product Development Internship    1188
# Please specify your starting date for the Product Growth Internship         1188
# Please indicate the number of hours per week on the Internship Program      1188
# Length: 84, dtype: int64

# %%
df.isnull().sum()
# Out:
# Name                                                                           0
# Squad Number                                                                1188
# Preferred Language                                                            19
# Virtual Internship Group Category                                              1
# Age                                                                            0
#                                                                             ...
# Please specify your starting date for the Product Marketing Internship       716
# Please specify your starting date for the Product Design Internship          587
# Please specify your starting date for the Product Development Internship     662
# Please specify your starting date for the Product Growth Internship          889
# Please indicate the number of hours per week on the Internship Program         0
# Length: 84, dtype: int64

# %%
# state which values in the rows of each column are populated or not by displaying true or false values
df.isna()
# Out:
#        Name  Squad Number  \
# 0     False          True
# 1     False          True
# 2     False          True
# 3     False          True
# 4     False          True
# ...     ...           ...
# 1183  False          True
# 1184  False          True
# 1185  False          True
# 1186  False          True
# 1187  False          True
#
#       Do you have any preferred language of communication?  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 1183                                              False
# 1184                                              False
# 1185                                              False
# 1186                                              False
# ...

# %%
# casting 
# List all the datatypes of the dataset

df.dtypes
# Out:
# Name                                                                             object
# Squad Number                                                                    float64
# Do you have any preferred language of communication?                             object
# What Group Virtual Internship Program are you interested in registering for      object
# Age                                                                             float64
#                                                                                  ...
# Which cohorts are you available to start the Product Marketing Internship?       object
# Which cohorts are you available to start the Product Design Internship?          object
# Which cohorts are you available to start the Product Development Internship?     object
# Which cohorts are you available to start the Product Growth Internship?          object
# How many hours per week are you able to give to the internship program?          object
# ...

# %%
df.rename(columns={'What Group Virtual Internship Program are you interested in registering for':'Virtual Internship Group Category'},inplace=True)
df
# Out:
#          Name  Squad Number  \
# 1111   Holden           NaN
# 46    Katelyn           NaN
# 78     Cooper           NaN
# 524      Mila           NaN
# 1152   Joshua           NaN
# ...       ...           ...
# 427     Belen           NaN
# 296     Jerry           NaN
# 152     Atlas           NaN
# 1116   Sophie           NaN
# 452     Ariel           NaN
#
#      Do you have any preferred language of communication?  \
# 1111                                            English
# 46                                              English
# 78                                              English
# 524                                             English
# 1152                                            English
# ...                                                 ...
# 427                                                  No
# 296                                             English
# 152                                             English
# ...

# %%
df.head()
# Out:
#          Name  Squad Number  \
# 1111   Holden           NaN
# 46    Katelyn           NaN
# 78     Cooper           NaN
# 524      Mila           NaN
# 1152   Joshua           NaN
#
#      Do you have any preferred language of communication?  \
# 1111                                            English
# 46                                              English
# 78                                              English
# 524                                             English
# 1152                                            English
#
#                       Virtual Internship Group Category  Age        City  \
# 1111                   Product Marketing,Product Design   16     Fishers
# 46    Product Design,Product Development,Product Gro...   16     Windsor
# 78                                  Product Development   16     Burnaby
# 524               Product Development,Product Marketing   16  Mirpur AJK
# 1152                                Product Development   16    San Jose
#
# ...

# %%
df.head(5)
# Out:
#          Name  Squad Number  \
# 46    Katelyn           NaN
# 78     Cooper           NaN
# 1152   Joshua           NaN
# 524      Mila           NaN
# 1111   Holden           NaN
#
#      Do you have any preferred language of communication?  \
# 46                                              English
# 78                                              English
# 1152                                            English
# 524                                             English
# 1111                                            English
#
#                       Virtual Internship Group Category  Age        City  \
# 46    Product Design,Product Development,Product Gro...   16     Windsor
# 78                                  Product Development   16     Burnaby
# 1152                                Product Development   16    San Jose
# 524               Product Development,Product Marketing   16  Mirpur AJK
# 1111                   Product Marketing,Product Design   16     Fishers
#
# ...

# %%
df.rename(columns={'What Group Virtual Internship Program are you interested in registering for':'Virtual Internship Group Category'},inplace=True)
df
# Out:
#          Name  Squad Number  \
# 1111   Holden           NaN
# 46    Katelyn           NaN
# 78     Cooper           NaN
# 524      Mila           NaN
# 1152   Joshua           NaN
# ...       ...           ...
# 427     Belen           NaN
# 296     Jerry           NaN
# 152     Atlas           NaN
# 1116   Sophie           NaN
# 452     Ariel           NaN
#
#      Do you have any preferred language of communication?  \
# 1111                                            English
# 46                                              English
# 78                                              English
# 524                                             English
# 1152                                            English
# ...                                                 ...
# 427                                                  No
# 296                                             English
# 152                                             English
# ...

# %%
# rename selected columns for the dataset

df.rename(columns={'In case we are not able to accommodate your primary role request, please select other roles you would be willing to take on.':'Please select other roles if you not selected for the primary role'},inplace=True)

df.rename(columns={'For the Product Growth Internship, what is your desired role?':'State your desired role for the Product Growth Internship'},inplace=True)

df.rename(columns={'In case we are not able to accommodate your primary role request due to cohort limitations, what other roles would you be willing to take on?':'Please select other roles if we cannot accommodiate your primary role request'},inplace=True)

df.rename(columns={'For the Product Marketing Internship, what is your desired role?':'State your desired role for the Product Marketing Internship'},inplace=True)

df.rename(columns={'In case we are not able to accommodate your primary role request, what other roles would you be willing to take on?':' Please select other roles if you not selected for the primary role'},inplace=True)

df.rename(columns={'Which cohorts are you available to start the Product Marketing Internship?':'Please specify your starting date for the Product Marketing Internship'},inplace=True)

df.rename(columns={'Which cohorts are you available to start the Product Design Internship?':'Please specify your starting date for the Product Design Internship'},inplace=True)

df.rename(columns={'Which cohorts are you available to start the Product Development Internship?':'Please specify your starting date for the Product Development Internship'},inplace=True)

df.rename(columns={'Which cohorts are you available to start the Product Growth Internship?':'Please specify your starting date for the Product Growth Internship'},inplace=True)

df.rename(columns={'How many hours per week are you able to give to the internship program?':'Please indicate the number of hours per week on the Internship Program'},inplace=True)

df
# Out:
#          Name  Squad Number  \
# 1111   Holden           NaN
# 46    Katelyn           NaN
# 78     Cooper           NaN
# 524      Mila           NaN
# 1152   Joshua           NaN
# ...       ...           ...
# 427     Belen           NaN
# 296     Jerry           NaN
# 152     Atlas           NaN
# 1116   Sophie           NaN
# 452     Ariel           NaN
#
#      Do you have any preferred language of communication?  \
# 1111                                            English
# 46                                              English
# 78                                              English
# 524                                             English
# 1152                                            English
# ...                                                 ...
# 427                                                  No
# 296                                             English
# 152                                             English
# ...

# %%
df.head()
# Out:
#          Name  Squad Number  \
# 46    Katelyn           NaN
# 78     Cooper           NaN
# 1152   Joshua           NaN
# 524      Mila           NaN
# 1111   Holden           NaN
#
#      Do you have any preferred language of communication?  \
# 46                                              English
# 78                                              English
# 1152                                            English
# 524                                             English
# 1111                                            English
#
#                       Virtual Internship Group Category  Age        City  \
# 46    Product Design,Product Development,Product Gro...   16     Windsor
# 78                                  Product Development   16     Burnaby
# 1152                                Product Development   16    San Jose
# 524               Product Development,Product Marketing   16  Mirpur AJK
# 1111                   Product Marketing,Product Design   16     Fishers
#
# ...

# %%
# Drops 'Country 1' column
df2=df.drop(["Country 1"], axis = 1, inplace=True)
print(df2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [92], in <cell line: 2>()
#       1 # Drops 'Country 1' column
# ----> 2 df2=df.drop(["Country 1"], axis = 1, inplace=True)
#       3 print(df2)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
# ...

# %%
df2

# %%
df.rename(columns={'Do you have any preferred language of communication?':'Preferred Language'},inplace=True)

# %%
df
# Out:
#          Name  Squad Number Preferred Language  \
# 46    Katelyn           NaN            English
# 78     Cooper           NaN            English
# 1152   Joshua           NaN            English
# 524      Mila           NaN            English
# 1111   Holden           NaN            English
# ...       ...           ...                ...
# 427     Belen           NaN                 No
# 296     Jerry           NaN            English
# 152     Atlas           NaN            English
# 1116   Sophie           NaN            English
# 452     Ariel           NaN            English
#
#                       Virtual Internship Group Category  Age          City  \
# 46    Product Design,Product Development,Product Gro...   16       Windsor
# 78                                  Product Development   16       Burnaby
# 1152                                Product Development   16      San Jose
# 524               Product Development,Product Marketing   16    Mirpur AJK
# ...

# %%
df.head()
# Out:
#          Name  Squad Number Preferred Language  \
# 46    Katelyn           NaN            English
# 78     Cooper           NaN            English
# 1152   Joshua           NaN            English
# 524      Mila           NaN            English
# 1111   Holden           NaN            English
#
#                       Virtual Internship Group Category  Age        City  \
# 46    Product Design,Product Development,Product Gro...   16     Windsor
# 78                                  Product Development   16     Burnaby
# 1152                                Product Development   16    San Jose
# 524               Product Development,Product Marketing   16  Mirpur AJK
# 1111                   Product Marketing,Product Design   16     Fishers
#
#        Country    Region Time Zone  current occupation?  ...  \
# 46      Canada  Americas  Americas  High School Student  ...
# 78      Canada  Americas  Americas  High School Student  ...
# ...

# %%
df.rename(columns={'current occupation?':'Current Occupation'},inplace=True)

# %%
df.head()
# Out:
#          Name  Squad Number Preferred Language  \
# 46    Katelyn           NaN            English
# 78     Cooper           NaN            English
# 1152   Joshua           NaN            English
# 524      Mila           NaN            English
# 1111   Holden           NaN            English
#
#                       Virtual Internship Group Category  Age        City  \
# 46    Product Design,Product Development,Product Gro...   16     Windsor
# 78                                  Product Development   16     Burnaby
# 1152                                Product Development   16    San Jose
# 524               Product Development,Product Marketing   16  Mirpur AJK
# 1111                   Product Marketing,Product Design   16     Fishers
#
#      Country    Region Time Zone   Current Occupation  ...  \
# 46       USA  Americas  Americas  High School Student  ...
# 78       USA  Americas  Americas  High School Student  ...
# ...

# %% [markdown]
# ### Data Cleaning Process

# %% [markdown]
# ### checking for missing values

# %%
df.isnull().sum() # checking missing values
# Out:
# Name                                                                           0
# Squad Number                                                                1188
# Preferred Language                                                            19
# Virtual Internship Group Category                                              1
# Age                                                                            0
#                                                                             ...
# Please specify your starting date for the Product Marketing Internship       716
# Please specify your starting date for the Product Design Internship          587
# Please specify your starting date for the Product Development Internship     662
# Please specify your starting date for the Product Growth Internship          889
# Please indicate the number of hours per week on the Internship Program         0
# Length: 84, dtype: int64

# %%
# Replace the missing values in the column "Age"

mean_value2 =df["Age"].mean()
mean_value2
# Out:
# 23.946809764309766

# %%
# Using the mean value to replace the missing records
df["Age"].fillna(mean_value2, inplace=True)

# %%
# confirm change
df.isnull().sum()
# Out:
# Name                                                                           0
# Squad Number                                                                1188
# Preferred Language                                                            19
# Virtual Internship Group Category                                              1
# Age                                                                            0
#                                                                             ...
# Please specify your starting date for the Product Marketing Internship       716
# Please specify your starting date for the Product Design Internship          587
# Please specify your starting date for the Product Development Internship     662
# Please specify your starting date for the Product Growth Internship          889
# Please indicate the number of hours per week on the Internship Program         0
# Length: 84, dtype: int64

# %%
# Replace the missing values in the column "Squad Number"

mean_value =df["Squad Number"].mean()
mean_value
# Out:
# nan

# %%
# Using the mean value to replace the missing records
df["Squad Number"].fillna(mean_value, inplace=True)

# %%
# confirm change
df.isnull().sum()
# Out:
# Name                                                                           0
# Squad Number                                                                1188
# Preferred Language                                                            19
# Virtual Internship Group Category                                              1
# Age                                                                            0
#                                                                             ...
# Please specify your starting date for the Product Marketing Internship       716
# Please specify your starting date for the Product Design Internship          587
# Please specify your starting date for the Product Development Internship     662
# Please specify your starting date for the Product Growth Internship          889
# Please indicate the number of hours per week on the Internship Program         0
# Length: 84, dtype: int64

# %%
# Dropping the missing values from other columns
df4 = df.dropna()
df4.isnull().sum()
# Out:
# Name                                                                        0.0
# Squad Number                                                                0.0
# Preferred Language                                                          0.0
# Virtual Internship Group Category                                           0.0
# Age                                                                         0.0
#                                                                            ...
# Please specify your starting date for the Product Marketing Internship      0.0
# Please specify your starting date for the Product Design Internship         0.0
# Please specify your starting date for the Product Development Internship    0.0
# Please specify your starting date for the Product Growth Internship         0.0
# Please indicate the number of hours per week on the Internship Program      0.0
# Length: 84, dtype: float64

# %%
import pandas as pd
import numpy as np
import seaborn as sns

df=pd.read_csv('Squad Matching data.csv')

# %%
df.rename(columns={'What Group Virtual Internship Program are you interested in registering for':'Virtual Internship Group Category'},inplace=True)
# rename selected columns for the dataset

df.rename(columns={'In case we are not able to accommodate your primary role request, please select other roles you would be willing to take on.':'Please select other roles if you not selected for the primary role'},inplace=True)

df.rename(columns={'For the Product Growth Internship, what is your desired role?':'State your desired role for the Product Growth Internship'},inplace=True)

df.rename(columns={'In case we are not able to accommodate your primary role request due to cohort limitations, what other roles would you be willing to take on?':'Please select other roles if we cannot accommodiate your primary role request'},inplace=True)

df.rename(columns={'For the Product Marketing Internship, what is your desired role?':'State your desired role for the Product Marketing Internship'},inplace=True)

df.rename(columns={'In case we are not able to accommodate your primary role request, what other roles would you be willing to take on?':' Please select other roles if you not selected for the primary role'},inplace=True)

df.rename(columns={'Which cohorts are you available to start the Product Marketing Internship?':'Please specify your starting date for the Product Marketing Internship'},inplace=True)

df.rename(columns={'Which cohorts are you available to start the Product Design Internship?':'Please specify your starting date for the Product Design Internship'},inplace=True)

df.rename(columns={'Which cohorts are you available to start the Product Development Internship?':'Please specify your starting date for the Product Development Internship'},inplace=True)

df.rename(columns={'Which cohorts are you available to start the Product Growth Internship?':'Please specify your starting date for the Product Growth Internship'},inplace=True)

df.rename(columns={'How many hours per week are you able to give to the internship program?':'Please indicate the number of hours per week on the Internship Program'},inplace=True)

df.rename(columns={'current occupation?':'Current Occupation'},inplace=True)

# %%
df.rename(columns={'Do you have any preferred language of communication?':'Preferred Language'},inplace=True)

# %%
df.rename(columns={'current occupation?':'Current Occupation'},inplace=True)

# %%
df.rename(columns={'current occupation?':'Current Occupation'},inplace=True)

# %%
df.head(5)
# Out:
#       Name  Squad Number                                 Preferred Language  \
# 0  Grayson           NaN  i prefer english but i am also able to communi...
# 1    Jonas           NaN                                            English
# 2    Ronan           NaN               English and Spanish are good for me.
# 3    Dulce           NaN                                            spanish
# 4   Evelyn           NaN                                            Spanish
#
#                   Virtual Internship Group Category   Age  \
# 0                 Product Marketing,Product Growth   23.0
# 1  Product Marketing,Product Growth ,Product Design  23.0
# 2                                    Product Design  34.0
# 3                                    Product Design  38.0
# 4                                 Product Marketing  22.0
#
#                       City    Country    Region          Time Zone  \
# 0       bordj bou arreridj    Algeria      MENA      Europe,Africa
# ...

# %%
# Drops 'Country 1' column
df5=df.drop(["Country 1"], axis = 1, inplace=True)
print(df5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [22], in <cell line: 2>()
#       1 # Drops 'Country 1' column
# ----> 2 df5=df.drop(["Country 1"], axis = 1, inplace=True)
#       3 print(df5)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
# ...

# %%
df
# Out:
#            Name  Squad Number  \
# 0       Grayson           NaN
# 1         Jonas           NaN
# 2         Ronan           NaN
# 3         Dulce           NaN
# 4        Evelyn           NaN
# ...         ...           ...
# 1183  Johnathan           NaN
# 1184     Adriel           NaN
# 1185      Reyna           NaN
# 1186      Uriel           NaN
# 1187    Esteban           NaN
#
#                                      Preferred Language  \
# 0     i prefer english but i am also able to communi...
# 1                                               English
# 2                  English and Spanish are good for me.
# 3                                               spanish
# 4                                               Spanish
# ...                                                 ...
# 1183                                            English
# 1184  English is the language I am most comfortable ...
# 1185                                            English
# ...

# %% [markdown]
# ### Check to see if any null standard values in the categorical categorical column values

# %%
df['Age'].value_counts()
# Out:
# 21.00    179
# 22.00    158
# 23.00    131
# 24.00    111
# 20.00    106
# 25.00     97
# 26.00     69
# 19.00     68
# 27.00     46
# 30.00     32
# 29.00     29
# 28.00     29
# 18.00     23
# 31.00     15
# 34.00     14
# 33.00     13
# 32.00     12
# 36.00      8
# 35.00      8
# 17.00      6
# 38.00      6
# 37.00      5
# 16.00      5
# 42.00      4
# 41.00      3
# 39.00      3
# 40.00      2
# 18.70      1
# 45.00      1
# 46.00      1
# 54.00      1
# 21.11      1
# 47.00      1
# Name: Age, dtype: int64

# %%
(df['Age'].value_counts()).plot(kind='bar',figsize =(20,10))
# Out:
# <AxesSubplot:>

# %%
df['Squad Number'].value_counts() # squad number is empty
# Out:
# Series([], Name: Squad Number, dtype: int64)

# %%
(df['Age'].value_counts()).plot(kind='bar',figsize =(20,10))

# %%
df['Preferred Language'].value_counts()
# Out:
# English                      620
# No                           113
# Urdu                          33
# english                       25
# no                            16
#                             ...
# Nepali, Hindi and English      1
# Englisj                        1
# None, only English             1
# No, English only               1
# Vietnamese                     1
# Name: Preferred Language, Length: 256, dtype: int64

# %%
(df['Preferred Language'].value_counts()).plot(kind='bar',figsize =(60,10))
# Out:
# <AxesSubplot:>

# %%
df['Virtual Internship Group Category'].value_counts()
# Out:
# Product Design                                                          289
# Product Development                                                     220
# Product Marketing                                                       173
# Product Design,Product Development                                       57
# Product Marketing,Product Design                                         47
# Product Marketing,Product Design,Product Development,Product Growth      44
# Product Marketing,Product Growth                                         42
# Product Growth                                                           41
# Product Development,Product Growth                                       39
# Product Design,Product Marketing                                         38
# Product Development,Product Design                                       28
# Product Design,Product Development,Product Growth                        18
# ...

# %%
(df['Virtual Internship Group Category'].value_counts()).plot(kind='bar',figsize =(20,10))
# Out:
# <AxesSubplot:>

# %%
df['Name'].value_counts()
# Out:
# Grayson    1
# Giselle    1
# Trinity    1
# Malachi    1
# Norah      1
#           ..
# Barrett    1
# Naomi      1
# Chris      1
# Ana        1
# Esteban    1
# Name: Name, Length: 1188, dtype: int64

# %%
(df['Name'].value_counts()).plot(kind='bar',figsize =(200,10))
# Out:
# <AxesSubplot:>

# %%
df['City'].value_counts()
# Out:
# Lagos                  97
# Karachi                54
# Cairo                  39
# Lahore                 36
# Islamabad              31
#                        ..
# Ikotun                  1
# Enugu, Nigeria          1
# Ile-Ife, Osun State     1
# Ile-ife                 1
# Ho Chi Minh             1
# Name: City, Length: 563, dtype: int64

# %%
(df['City'].value_counts()).plot(kind='bar',figsize =(100,10))
# Out:
# <AxesSubplot:>

# %%
df['Country'].value_counts()
# Out:
# Pakistan        247
# USA             230
# Nigeria         229
# UAE              68
# Egypt            60
#                ...
# Kosovo            1
# Latvia            1
# North Cyprus      1
# Lithuania         1
# Georgia           1
# Name: Country, Length: 61, dtype: int64

# %%
df['Region'].value_counts()
# Out:
# APAC        349
# Americas    303
# Africa      258
# MENA        152
# Europe      122
# Name: Region, dtype: int64

# %%
df['Region'].value_counts().plot(kind='bar',figsize =(20,10))
# Out:
# <AxesSubplot:>

# %%
df['Time Zone'].value_counts()
# Out:
# Asia                                                308
# Americas                                            276
# Africa                                              216
# Europe                                              100
# Any/No preference                                    90
#                                                    ...
# Europe,Africa,Any/No preference                       1
# Africa,Europe,Any/No preference                       1
# Europe,Africa,Asia                                    1
# Americas,Europe,Australia                             1
# Americas,Australia,Europe,Asia,Any/No preference      1
# Name: Time Zone, Length: 64, dtype: int64

# %%
df['Time Zone'].value_counts().plot(kind='bar',figsize =(20,10))
# Out:
# <AxesSubplot:>

# %%
df['Current Operation'].value_counts()
# Out:
# University Student                   542
# Recently Graduated and Unemployed    299
# Currently Unemployed                 189
# Employed                             138
# High School Student                   19
# Name: Current Operation, dtype: int64

# %%
df['Current Operation'].value_counts().plot(kind='bar',figsize =(20,10))
# Out:
# <AxesSubplot:>

# %%
df['Please select other roles if you not selected for the primary role'].value_counts()
# Out:
# Project Manager                                                          30
# Product Manager                                                          29
# Software Developer                                                       26
# Web Developer                                                            22
# Data Analyst                                                             21
#                                                                          ..
# Web Designer,Software Developer,Data Analyst,Data Scientist               1
# Cloud Developer,Project Manager,DevOPs Manager                            1
# Project Manager,Data Scientist                                            1
# Data Analyst,Data Scientist,Product Manager,UI Developer                  1
# Web Developer,Cloud Developer,AI Engineer ,ML Engineer,Data Scientist     1
# Name: Please select other roles if you not selected for the primary role, Length: 293, dtype: int64

# %%
df['Please select other roles if you not selected for the primary role'].value_counts().plot(kind='bar',figsize =(100,10))
# Out:
# <AxesSubplot:>

# %%
df['State your desired role for the Product Growth Internship'].value_counts()
# Out:
# Product Manager                     76
# Data Analyst                        49
# Growth Marketer                     37
# Project Manager                     31
# Business Analyst                    28
# Customer Success Manager            20
# Account Manager                     16
# Market Researcher                   15
# Content Writer                      13
# Sales Development Representative     8
# SEM Manager                          7
# Name: State your desired role for the Product Growth Internship, dtype: int64

# %%
df['State your desired role for the Product Growth Internship'].value_counts().plot(kind='bar',figsize =(20,10))
# Out:
# <AxesSubplot:>

# %%
df['Please specify your starting date for the Product Marketing Internship'].value_counts()
# Out:
# Starting on 22nd August                                                       162
# Starting on 15th August                                                       146
# Starting on 12th September                                                     86
# Starting on 15th August,Starting on 22nd August                                43
# Starting on 22nd August,Starting on 15th August                                15
# I would prefer a later cohort                                                  15
# I would prefer a later cohort,Starting on 12th September                        2
# Starting on 12th September,I would prefer a later cohort                        2
# Starting on 12th September,Starting on 15th August,Starting on 22nd August      1
# Name: Please specify your starting date for the Product Marketing Internship, dtype: int64

# %%
df['Please specify your starting date for the Product Marketing Internship'].value_counts().plot(kind='bar',figsize =(20,10))
# Out:
# <AxesSubplot:>

# %%
df['Please specify your starting date for the Product Design Internship'].value_counts()
# Out:
# Starting on 5th September                                                          250
# Starting on 22nd August                                                            192
# Starting on 22nd August,Starting on 5th September                                   77
# Starting on 5th September,Starting on 22nd August                                   22
# I would prefer a later cohort                                                       17
# Starting on 3rd October                                                             14
# Starting on 5th September,Starting on 3rd October                                   14
# Starting on 5th September,I would prefer a later cohort                              7
# Starting on 3rd October,Starting on 5th September                                    3
# I would prefer a later cohort,Starting on 5th September                              2
# Starting on 3rd October,Starting on 22nd August                                      1
# ...

# %%
df['Please specify your starting date for the Product Growth Internship'].value_counts()
# Out:
# Starting on 5th September        238
# I would prefer a later cohort     49
# Starting on 3rd October           12
# Name: Please specify your starting date for the Product Growth Internship, dtype: int64

# %%
df['Please specify your starting date for the Product Growth Internship'].value_counts().plot(kind='bar',figsize =(20,10))
# Out:
# <AxesSubplot:>

# %%
df['Please indicate the number of hours per week on the Internship Program'].value_counts()
# Out:
# 10-15 hours    589
# 15-20 hours    372
# 20-25 hours    227
# Name: Please indicate the number of hours per week on the Internship Program, dtype: int64

# %%
df['Please indicate the number of hours per week on the Internship Program'].value_counts().plot(kind='bar',figsize =(20,10))
# Out:
# <AxesSubplot:>

# %%
#Please specify your starting date for the Product Growth Internship

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1188 entries, 0 to 1187
# Data columns (total 84 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   Name                                                                                                                                1188 non-null   object
#  1   Squad Number                                                                                                                        0 non-null      float64
#  2   Preferred Language                                                                                                                  1169 non-null   object
# ...

# %% [markdown]
# ### Test to see how many duplicates are on each column of the dataset

# %%
# test to see if any duplicates

df.groupby('Name')['Name'].agg('count')
# Out:
# Name
# Aaliyah    1
# Aarav      1
# Aaron      1
# Abbas      1
# Abby       1
#           ..
# Zayne      1
# Zion       1
# Zoe        1
# Zoey       1
# Zuri       1
# Name: Name, Length: 1188, dtype: int64

# %%
# test to see if any duplicates

df.groupby('Squad Number')['Squad Number'].agg('count')
# Out:
# Series([], Name: Squad Number, dtype: int64)

# %%
# test to see if any duplicates

df.groupby('Preferred Language')['Preferred Language'].agg('count')
# Out:
# Preferred Language
#  English, Arabic                1
# -                               1
# 1)English 2)French 3)Arabic     1
# Arabia and English              1
# Arabic                         13
#                                ..
# not really                      2
# spanish                         2
# turkish                         1
# urdu                            5
# urdu/hindi                      1
# Name: Preferred Language, Length: 256, dtype: int64

# %%
# test to see if any duplicates

df.groupby('Virtual Internship Group Category')['Virtual Internship Group Category'].agg('count')
# Out:
# Virtual Internship Group Category
# Product Design                                                          289
# Product Design,Product Development                                       57
# Product Design,Product Development,Product Growth                        18
# Product Design,Product Development,Product Growth ,Product Marketing      3
# Product Design,Product Development,Product Marketing                      4
# Product Design,Product Development,Product Marketing,Product Growth       1
# Product Design,Product Growth                                             4
# Product Design,Product Growth ,Product Development                        3
# Product Design,Product Marketing                                         38
# Product Design,Product Marketing,Product Development                      1
# Product Design,Product Marketing,Product Growth                           4
# Product Development                                                     220
# ...

# %%
# test to see if any duplicates

df.groupby('Age')['Age'].agg('count')
# Out:
# Age
# 16.00      5
# 17.00      6
# 18.00     23
# 18.70      1
# 19.00     68
# 20.00    106
# 21.00    179
# 21.11      1
# 22.00    158
# 23.00    131
# 24.00    111
# 25.00     97
# 26.00     69
# 27.00     46
# 28.00     29
# 29.00     29
# 30.00     32
# 31.00     15
# 32.00     12
# 33.00     13
# 34.00     14
# 35.00      8
# 36.00      8
# 37.00      5
# 38.00      6
# 39.00      3
# 40.00      2
# 41.00      3
# 42.00      4
# 45.00      1
# 46.00      1
# 47.00      1
# 54.00      1
# Name: Age, dtype: int64

# %%
# test to see if any duplicates

df.groupby('City')['City'].agg('count')
# Out:
# City
# 1                                     1
# 16b, ogbunike street lekki phase 1    1
# 6th of October                        1
# AHMEDABAD                             1
# ANGELES CITY                          1
#                                      ..
# seattle                               1
# sylhet                                1
# wah cantt                             1
# İstanbul                              4
# İzmir                                 1
# Name: City, Length: 563, dtype: int64

# %%
# test to see if any duplicates

df.groupby('Country')['Country'].agg('count')
# Out:
# Country
# Algeria             2
# Argentina           5
# Armenia             2
# Autriche            1
# Azerbaijan          2
#                  ...
# USA               230
# Ukraine             2
# United Kingdom     41
# Venezuela           1
# Vietnam             2
# Name: Country, Length: 61, dtype: int64

# %%
# test to see if any duplicates

df.groupby('Region')['Region'].agg('count')
# Out:
# Region
# APAC        349
# Africa      258
# Americas    303
# Europe      122
# MENA        152
# Name: Region, dtype: int64

# %%
# test to see if any duplicates

df.groupby('Time Zone')['Time Zone'].agg('count')
# Out:
# Time Zone
# Africa                                    216
# Africa,Americas                             6
# Africa,Americas,Any/No preference           1
# Africa,Americas,Europe                      1
# Africa,Any/No preference                    5
#                                          ...
# Europe,Americas,Africa                      1
# Europe,Americas,Asia,Any/No preference      1
# Europe,Any/No preference                    2
# Europe,Asia                                11
# Europe,Asia,Any/No preference               1
# Name: Time Zone, Length: 64, dtype: int64

# %%
# Current operation - rename the column first

# test to see if any duplicates

df.groupby('Current Operation')['Current Operation'].agg('count')
# Out:
# Current Operation
# Currently Unemployed                 189
# Employed                             138
# High School Student                   19
# Recently Graduated and Unemployed    299
# University Student                   542
# Name: Current Operation, dtype: int64

# %%
# test to see if any duplicates

df.groupby('Please select other roles if you not selected for the primary role')['Please select other roles if you not selected for the primary role'].agg('count')
# Out:
# Please select other roles if you not selected for the primary role
# AI Engineer                                                                                              2
# AI Engineer ,Cloud Developer,ML Engineer                                                                 1
# AI Engineer ,Cloud Developer,Software Developer,ML Engineer                                              1
# AI Engineer ,Data Analyst                                                                                1
# AI Engineer ,Data Analyst,Data Scientist,ML Engineer,Software Developer                                  1
#                                                                                                         ..
# Web Developer,Web Designer,Product Designer                                                              1
# Web Developer,Web Designer,Product Designer,Cloud Developer,DevOPs Manager                               1
# ...

# %%
# test to see if any duplicates

df.groupby('State your desired role for the Product Growth Internship')['State your desired role for the Product Growth Internship'].agg('count')
# Out:
# State your desired role for the Product Growth Internship
# Account Manager                     16
# Business Analyst                    28
# Content Writer                      13
# Customer Success Manager            20
# Data Analyst                        49
# Growth Marketer                     37
# Market Researcher                   15
# Product Manager                     76
# Project Manager                     31
# SEM Manager                          7
# Sales Development Representative     8
# Name: State your desired role for the Product Growth Internship, dtype: int64

# %%
# test to see if any duplicates

df.groupby('Please select other roles if you not selected for the primary role')['Please select other roles if you not selected for the primary role'].agg('count')
# Out:
# Please select other roles if you not selected for the primary role
# AI Engineer                                                                                              2
# AI Engineer ,Cloud Developer,ML Engineer                                                                 1
# AI Engineer ,Cloud Developer,Software Developer,ML Engineer                                              1
# AI Engineer ,Data Analyst                                                                                1
# AI Engineer ,Data Analyst,Data Scientist,ML Engineer,Software Developer                                  1
#                                                                                                         ..
# Web Developer,Web Designer,Product Designer                                                              1
# Web Developer,Web Designer,Product Designer,Cloud Developer,DevOPs Manager                               1
# ...

# %%
# test to see if any duplicates

df.groupby('Please specify your starting date for the Product Marketing Internship')['Please specify your starting date for the Product Marketing Internship'].agg('count')
# Out:
# Please specify your starting date for the Product Marketing Internship
# I would prefer a later cohort                                                  15
# I would prefer a later cohort,Starting on 12th September                        2
# Starting on 12th September                                                     86
# Starting on 12th September,I would prefer a later cohort                        2
# Starting on 12th September,Starting on 15th August,Starting on 22nd August      1
# Starting on 15th August                                                       146
# Starting on 15th August,Starting on 22nd August                                43
# Starting on 22nd August                                                       162
# Starting on 22nd August,Starting on 15th August                                15
# Name: Please specify your starting date for the Product Marketing Internship, dtype: int64

# %%
# test to see if any duplicates

df.groupby('Please specify your starting date for the Product Design Internship')['Please specify your starting date for the Product Design Internship'].agg('count')
# Out:
# Please specify your starting date for the Product Design Internship
# I would prefer a later cohort                                                       17
# I would prefer a later cohort,Starting on 5th September                              2
# Starting on 22nd August                                                            192
# Starting on 22nd August,Starting on 5th September                                   77
# Starting on 3rd October                                                             14
# Starting on 3rd October,Starting on 22nd August                                      1
# Starting on 3rd October,Starting on 5th September                                    3
# Starting on 3rd October,Starting on 5th September,I would prefer a later cohort      1
# Starting on 5th September                                                          250
# Starting on 5th September,I would prefer a later cohort                              7
# ...

# %%
# test to see if any duplicates

df.groupby('Please specify your starting date for the Product Development Internship')['Please specify your starting date for the Product Development Internship'].agg('count')
# Out:
# Please specify your starting date for the Product Development Internship
# I would prefer a later cohort     52
# Starting on 3rd October           46
# Starting on 5th September        428
# Name: Please specify your starting date for the Product Development Internship, dtype: int64

# %%
# test to see if any duplicates

df.groupby('Please specify your starting date for the Product Growth Internship')['Please specify your starting date for the Product Growth Internship'].agg('count')
# Out:
# Please specify your starting date for the Product Growth Internship
# I would prefer a later cohort     49
# Starting on 3rd October           12
# Starting on 5th September        238
# Name: Please specify your starting date for the Product Growth Internship, dtype: int64

# %%
# test to see if any duplicates

df.groupby('Please indicate the number of hours per week on the Internship Program')['Please indicate the number of hours per week on the Internship Program'].agg('count')
# Out:
# Please indicate the number of hours per week on the Internship Program
# 10-15 hours    589
# 15-20 hours    372
# 20-25 hours    227
# Name: Please indicate the number of hours per week on the Internship Program, dtype: int64

# %%
# test to see if any duplicates

df.groupby('Preferred Language')['Preferred Language'].agg('count')

# %% [markdown]
# ### Check for unique values for each column of the dataset

# %%
# check the unique values for Name column

df['Name'].unique()
# Out:
# array(['Grayson', 'Jonas', 'Ronan', ..., 'Reyna', 'Uriel', 'Esteban'],
#       dtype=object)

# %%
# check the unique values for Squad Number column

df['Squad Number'].unique()
# Out:
# array([nan])

# %%
# check the unique values for Preferred column

df['Preferred Language'].unique()
# Out:
# array(['i prefer english but i am also able to communicate in french and arabic',
#        'English', 'English and Spanish are good for me.', 'spanish',
#        'Spanish', 'Español', 'English is okay', 'English Russians',
#        'french', 'English (I speak Azerbaijani, Russian)', 'No',
#        'English, Hindi, Bangla ', 'Bangla', 'no', 'Bengali', 'EN',
#        'Portuguese', 'English or Brazilian Portuguese', 'Português',
#        'English/portuguese', 'Brazilian Portuguese.',
#        'My primary language is portuguese, but I feel comfortable to communicate in english.',
#        'English is fine!', 'English, Portuguese',
#        'English and Portuguese.',
#        'No preference, but I do speak spanish and portuguese', 'French',
#        'English, Ukrainian, Russian', 'Punjabi/Hindi',
#        'English, Mandarin, Japanese', 'Turkish', 'English or French',
#        'English, Japanese',
#        "I can speak English and Vietnamese, and I'm comfortable with either.",
# ...

# %%
# check the unique values for Virtual Internship Group Category column

df['Virtual Internship Group Category'].unique()
# Out:
# array(['Product Marketing,Product Growth ',
#        'Product Marketing,Product Growth ,Product Design',
#        'Product Design', 'Product Marketing',
#        'Product Growth ,Product Development',
#        'Product Design,Product Marketing',
#        'Product Design,Product Development', 'Product Development',
#        'Product Marketing,Product Design,Product Development,Product Growth ',
#        'Product Marketing,Product Design,Product Growth ,Product Development',
#        'Product Development,Product Design,Product Growth ',
#        'Product Development,Product Growth ,Product Marketing',
#        'Product Design,Product Development,Product Growth ',
#        'Product Design,Product Development,Product Marketing',
#        'Product Marketing,Product Design',
#        'Product Development,Product Design',
#        'Product Development,Product Growth ', 'Product Growth',
#        'Product Marketing,Product Development',
# ...

# %%
# check the unique values for Age column

df['Age'].unique()
# Out:
# array([23.  , 34.  , 38.  , 22.  , 21.  , 25.  , 24.  , 33.  , 19.  ,
#        36.  , 27.  , 35.  , 26.  , 30.  , 18.  , 20.  , 16.  , 28.  ,
#        39.  , 31.  , 29.  , 32.  , 46.  , 18.7 , 45.  , 41.  , 17.  ,
#        42.  , 54.  , 21.11, 37.  , 47.  , 40.  ])

# %%
# check the unique values for City column

df['City'].unique()
# Out:
# array(['bordj bou arreridj', 'Algiers', 'Buenos Aires, Argentina',
#        'Mendoza', 'Tigre', 'Buenos Aires', 'Junín', 'Yerevan', 'Vienna',
#        'Baku', 'Cumilla', 'Dhaka', 'Sylhet',
#        'Dhaka, Dhaka Division, Bangladesh', 'sylhet', 'Barisal', 'Khulna',
#        'Brussesl', 'Anápolis, State of Goiás', 'Uberlândia', 'São Carlos',
#        'Nova Iguaçu', 'São Paulo', 'Curitiba', 'Botucatu',
#        'Feira de Santana', 'Palmas', 'SAO CARLOS', 'João Pessoa',
#        'Fortaleza', 'Yaoundé', 'Brampton', 'Toronto', 'Delta',
#        'Mississauga', 'Waterloo', 'Windsor', 'Montreal', 'Rouyn-Noranda',
#        'Vaughan', 'Waterloo, Ontario, Canada', 'Hamilton', 'Vancouver',
#        'Victoria', 'Moncton', 'Calgary', 'Burnaby', 'Edmonton',
#        'Scarborough', 'Leduc, Alberta', 'Winnipeg', 'Ottawa', 'Richmond',
#        'Montréal', 'Bogotá', 'Cairo', 'Mansoura', '6th of October',
#        'Tanta', 'alexandria', 'Giza', 'Alexandria', 'Sheikh zayed',
# ...

# %%
# check the unique values for Country column

df['Country'].unique()
# Out:
# array(['Algeria', 'Argentina', 'Armenia', 'Autriche', 'Azerbaijan',
#        'Bangladesh', 'Belgium', 'Brazil', 'Cameroun', 'Canada',
#        'Colombia', 'Egypt', 'Finland', 'France', 'Georgia', 'Germany',
#        'Ghana', 'India', 'Indonesia', 'Iran', 'Ireland', 'Israel',
#        'Italy', 'Jamaica', 'Jordan', 'Kenya', 'Kosovo', 'Latvia',
#        'Lebanon', 'Lithuania', 'Mexico', 'Morocco', 'Nepal',
#        'Netherlands', 'Nigeria', 'North Cyprus', 'North Macedonia',
#        'Pakistan', 'Panama', 'Philippines', 'Poland', 'Puerto Rico',
#        'Qatar', 'Romania', 'Rwanda', 'Saudi Arabia', 'South Africa',
#        'Spain', 'Sri Lanka', 'Sweden', 'Switzerland', 'Tanzania',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'UAE', 'Ukraine',
#        'United Kingdom', 'USA', 'Venezuela', 'Vietnam'], dtype=object)

# %%
# check the unique values for Region column

df['Region'].unique()
# Out:
# array(['MENA', 'Americas', 'Europe', 'APAC', 'Africa', nan], dtype=object)

# %%
# check the unique values for Timezone column

df['Time Zone'].unique()
# Out:
# array(['Europe,Africa', 'Africa,Europe', 'Americas', 'Any/No preference',
#        'Americas,Europe,Australia', 'Asia,Europe', 'Europe', 'Asia',
#        'Europe,Africa,Asia', 'Asia,Americas', 'Americas,Europe', 'Africa',
#        'Americas,Europe,Any/No preference', 'Americas,Any/No preference',
#        'Any/No preference,Africa', 'Africa,Any/No preference',
#        'Africa,Europe,Any/No preference',
#        'Any/No preference,Americas,Europe',
#        'Any/No preference,Africa,Europe',
#        'Europe,Africa,Any/No preference', 'Asia,Africa',
#        'Africa,Europe,Americas',
#        'Africa,Any/No preference,Europe,Americas', 'Europe,Americas',
#        'Europe,Asia', 'Asia,Any/No preference',
#        'Americas,Asia,Europe,Australia', 'Any/No preference,Americas',
#        'Any/No preference,Asia,Americas',
#        'Asia,Americas,Any/No preference',
#        'Asia,Americas,Europe,Australia', 'Asia,Africa,Europe,Americas',
# ...

# %%
# check the unique values for Current Occupation column

df['Current Operation'].unique()
# Out:
# array(['Recently Graduated and Unemployed', 'Employed',
#        'University Student', 'Currently Unemployed',
#        'High School Student', nan], dtype=object)

# %%
# check the unique values for Squad Number column

df['Please select other roles if you not selected for the primary role'].unique()
# Out:
# array([nan, 'Web Developer,Data Analyst,Data Scientist',
#        'Software Developer,Product Designer,Web Designer,UI Developer ',
#        'Product Manager,Product Designer,Data Analyst,Data Scientist,Project Manager',
#        'Data Analyst',
#        'Web Designer,UI Developer ,Web Developer,Software Developer,ML Engineer,Data Analyst,Data Scientist',
#        'Software Developer,Data Analyst,ML Engineer', 'Web Designer',
#        'Cloud Developer,DevOPs Manager,Software Developer,Web Developer,Data Analyst,Data Scientist',
#        'Web Developer,Cloud Developer,DevOPs Manager',
#        'Software Developer',
#        'Product Manager,Project Manager,Product Designer,DevOPs Manager',
#        'AI Engineer ,Software Developer,Web Designer,DevOPs Manager',
#        'Data Scientist,Web Designer,DevOPs Manager,Data Analyst',
#        'Web Developer,UI Developer ',
#        'Cloud Developer,AI Engineer ,ML Engineer,DevOPs Manager,Data Analyst,Data Scientist',
# ...

# %%
# check the unique values for State your desired role for the Product Growth Internship column

df['State your desired role for the Product Growth Internship'].unique()
# Out:
# array(['Growth Marketer', 'Sales Development Representative', nan,
#        'Data Analyst', 'SEM Manager', 'Product Manager',
#        'Customer Success Manager', 'Content Writer', 'Market Researcher',
#        'Project Manager', 'Business Analyst', 'Account Manager'],
#       dtype=object)

# %%
# check the unique values for Please select other roles if you not selected for the primary role column

df['Please select other roles if you not selected for the primary role'].unique()
# Out:
# array([nan, 'Web Developer,Data Analyst,Data Scientist',
#        'Software Developer,Product Designer,Web Designer,UI Developer ',
#        'Product Manager,Product Designer,Data Analyst,Data Scientist,Project Manager',
#        'Data Analyst',
#        'Web Designer,UI Developer ,Web Developer,Software Developer,ML Engineer,Data Analyst,Data Scientist',
#        'Software Developer,Data Analyst,ML Engineer', 'Web Designer',
#        'Cloud Developer,DevOPs Manager,Software Developer,Web Developer,Data Analyst,Data Scientist',
#        'Web Developer,Cloud Developer,DevOPs Manager',
#        'Software Developer',
#        'Product Manager,Project Manager,Product Designer,DevOPs Manager',
#        'AI Engineer ,Software Developer,Web Designer,DevOPs Manager',
#        'Data Scientist,Web Designer,DevOPs Manager,Data Analyst',
#        'Web Developer,UI Developer ',
#        'Cloud Developer,AI Engineer ,ML Engineer,DevOPs Manager,Data Analyst,Data Scientist',
# ...

# %%
# check the unique values for Please specify your starting date for the Product Marketing Internship column

df['Please specify your starting date for the Product Marketing Internship'].unique()
# Out:
# array(['Starting on 15th August,Starting on 22nd August',
#        'Starting on 12th September,Starting on 15th August,Starting on 22nd August',
#        nan, 'Starting on 22nd August,Starting on 15th August',
#        'I would prefer a later cohort', 'Starting on 22nd August',
#        'Starting on 15th August', 'Starting on 12th September',
#        'I would prefer a later cohort,Starting on 12th September',
#        'Starting on 12th September,I would prefer a later cohort'],
#       dtype=object)

# %%
# check the unique values for Please specify your starting date for the Product Design Internship column

df['Please specify your starting date for the Product Design Internship'].unique()
# Out:
# array([nan, 'Starting on 3rd October,Starting on 22nd August',
#        'Starting on 22nd August', 'Starting on 3rd October',
#        'Starting on 22nd August,Starting on 5th September',
#        'Starting on 5th September', 'I would prefer a later cohort',
#        'Starting on 5th September,Starting on 3rd October',
#        'Starting on 5th September,I would prefer a later cohort',
#        'Starting on 3rd October,Starting on 5th September',
#        'Starting on 5th September,Starting on 3rd October,I would prefer a later cohort',
#        'Starting on 5th September,Starting on 22nd August',
#        'I would prefer a later cohort,Starting on 5th September',
#        'Starting on 3rd October,Starting on 5th September,I would prefer a later cohort'],
#       dtype=object)

# %%
# check the unique values for Please specify your starting date for the Product Development Internship column

df['Please specify your starting date for the Product Development Internship'].unique()
# Out:
# array([nan, 'Starting on 3rd October', 'Starting on 5th September',
#        'I would prefer a later cohort'], dtype=object)

# %%
# check the unique values for Please specify your starting date for the Product Growth Internship column

df['Please specify your starting date for the Product Growth Internship'].unique()
# Out:
# array(['Starting on 5th September', 'Starting on 3rd October', nan,
#        'I would prefer a later cohort'], dtype=object)

# %%
# check the unique values for Please indicate the number of hours per week on the Internship Program column

df['Please indicate the number of hours per week on the Internship Program'].unique()
# Out:
# array(['20-25 hours', '10-15 hours', '15-20 hours'], dtype=object)

# %% [markdown]
# ### Checking for outliers in the dataset using the boxplot

# %%
# check for outliers in the dataset using boxplot 
import seaborn as sns
sns.boxplot(df["Product Management"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product Management'>

# %%
sns.boxplot(df["Project Management"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Project Management'>

# %%
sns.boxplot(df["Product Management"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product Management'>

# %%
sns.boxplot(df["Digital Marketing"])
# Out:
# <AxesSubplot:xlabel='Digital Marketing'>

# %%
df.columns
# Out:
# Index(['Name', 'Squad Number', 'Preferred Language',
#        'Virtual Internship Group Category', 'Age', 'City', 'Country', 'Region',
#        'Time Zone', 'Current Operation', 'School/University',
#        'What did you study at University/College?',
#        'Upskilling courses on online platforms like Udemy, Coursera, edX, or others?',
#        'Please describe what courses you have taken, if any.',
#        'Do you have any previous work or internship experience?',
#        'What is your preferred method of communication?', 'Product Management',
#        'Project Management', 'Digital Marketing', 'SEO/SEM', 'Paid Marketing',
#        'Influencer Marketing', 'Content Marketing', 'Email Marketing',
#        'Market Research', 'Graphic Design', 'Digital Illustration',
#        'Animation', 'Video Editing', 'Digital Content Creation', 'UX Design',
#        'UI Design', 'Product Design', 'Visual Design', 'Motion Design',
# ...

# %%
df.head(5)
# Out:
#       Name  Squad Number                                 Preferred Language  \
# 0  Grayson           NaN  i prefer english but i am also able to communi...
# 1    Jonas           NaN                                            English
# 2    Ronan           NaN               English and Spanish are good for me.
# 3    Dulce           NaN                                            spanish
# 4   Evelyn           NaN                                            Spanish
#
#                   Virtual Internship Group Category   Age  \
# 0                 Product Marketing,Product Growth   23.0
# 1  Product Marketing,Product Growth ,Product Design  23.0
# 2                                    Product Design  34.0
# 3                                    Product Design  38.0
# 4                                 Product Marketing  22.0
#
#                       City    Country    Region          Time Zone  \
# 0       bordj bou arreridj    Algeria      MENA      Europe,Africa
# ...

# %%
sns.boxplot(df["SEO/SEM"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SEO/SEM'>

# %%
sns.boxplot(df["Paid Marketing"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Paid Marketing'>

# %%
sns.boxplot(df["Influencer Marketing"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Influencer Marketing'>

# %%
sns.boxplot(df["Content Marketing"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Content Marketing'>

# %%
sns.boxplot(df["Email Marketing"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Email Marketing'>

# %%
sns.boxplot(df["Market Research"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Market Research'>

# %%
sns.boxplot(df["Graphic Design"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Graphic Design'>

# %%
sns.boxplot(df["Digital Illustration"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Digital Illustration'>

# %%
sns.boxplot(df["Animation"]) # found some outliers
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Animation'>

# %%
sns.boxplot(df["Video Editing"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Video Editing'>

# %%
max_video = df["Video Editing"].quantile(0.995)
max_video
# Out:
# 5.0

# %%
df[df["Video Editing"]>max_video]
# Out:
# Empty DataFrame
# ...

# %%
 sns.boxplot(df["Digital Content Creation"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Digital Content Creation'>

# %%
sns.boxplot(df["UX Design"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='UX Design'>

# %%
sns.boxplot(df["UI Design"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='UI Design'>

# %%
sns.boxplot(df["Product Design"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product Design'>

# %%
sns.boxplot(df["Visual Design"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Visual Design'>

# %%
sns.boxplot(df["Motion Design"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Motion Design'>

# %%
sns.boxplot(df["User Research"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='User Research'>

# %%
sns.boxplot(df["Business Analytics"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Business Analytics'>

# %%
sns.boxplot(df["Interaction Design"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Interaction Design'>

# %%
sns.boxplot(df["UX Writing"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='UX Writing'>

# %%
sns.boxplot(df["Content Strategy"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Content Strategy'>

# %%
sns.boxplot(df["Copywriting"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Copywriting'>

# %%
sns.boxplot(df["Web Design"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Web Design'>

# %%
sns.boxplot(df["UI Development"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='UI Development'>

# %%
sns.boxplot(df["Web Development"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Web Development'>

# %%
sns.boxplot(df["Software Development"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Software Development'>

# %%
sns.boxplot(df["Cloud Development"]) # find some outliers
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Cloud Development'>

# %%
# Choose the maximuim quantile to fill in the outliers

cloud = df["Video Editing"].quantile(0.995)
cloud
# Out:
# 5.0

# %%
df[df["Video Editing"]>cloud]
# Out:
# Empty DataFrame
# ...

# %%
sns.boxplot(df["Artificial Intelligence Engineering"]) # found some outliers
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Artificial Intelligence Engineering'>

# %%
# Choose the maximuim quantile to fill in the outliers

ai_eng = df["Artificial Intelligence Engineering"].quantile(0.995)
ai_eng
# Out:
# 5.0

# %%
df[df["Artificial Intelligence Engineering"]>ai_eng]
# Out:
# Empty DataFrame
# ...

# %%
sns.boxplot(df["Machine Learning Engineering"]) # found some outliers
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Machine Learning Engineering'>

# %%
# Choose the maximuim quantile to fill in the outliers



ml_eng = df["Machine Learning Engineering"].quantile(0.995)
ml_eng
# Out:
# 5.0

# %%
df[df["Machine Learning Engineering"]>ml_eng]
# Out:
# Empty DataFrame
# ...

# %%
sns.boxplot(df["DevOps Management"]) # found some outliers
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DevOps Management'>

# %%
# Choose the maximuim quantile to fill in the outliers



dev_ops = df["DevOps Management"].quantile(0.995)
dev_ops
# Out:
# 5.0

# %%
df[df["DevOps Management"]>dev_ops]
# Out:
# Empty DataFrame
# ...

# %%
sns.boxplot(df["Data Analytics"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Data Analytics'>

# %%
sns.boxplot(df["Data Science"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Data Science'>

# %%
sns.boxplot(df["Growth Marketing"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Growth Marketing'>

# %%
sns.boxplot(df["Sales"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sales'>

# %%
sns.boxplot(df["Customer Success Management"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Customer Success Management'>

# %%
sns.boxplot(df["Account Management"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Account Management'>

# %%
sns.boxplot(df["Content Writing"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Content Writing'>

# %%
sns.boxplot(df["Completing individual tasks on time"]) # found some outliers
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Completing individual tasks on time'>

# %%
# Choose the maximuim quantile to fill in the outliers

ind_tasks = df["Completing individual tasks on time"].quantile(0.995)
ind_tasks
# Out:
# 5.0

# %%
df[df["Completing individual tasks on time"]>ind_tasks]
# Out:
# Empty DataFrame
# ...

# %%
sns.boxplot(df["Seeking assistance when needed"]) # found some outliers
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Seeking assistance when needed'>

# %%
# Choose the maximuim quantile to fill in the outliers


seek_assist = df["Seeking assistance when needed"].quantile(0.995)
seek_assist
# Out:
# 5.0

# %%
df[df["Seeking assistance when needed"]>seek_assist]
# Out:
# Empty DataFrame
# ...

# %%
sns.boxplot(df["Identifying and solving problems as they arise"]) # found some outliers
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Identifying and solving problems as they arise'>

# %%
# Choose the maximuim quantile to fill in the outliers

sol = df["Identifying and solving problems as they arise"].quantile(0.995)
sol
# Out:
# 5.0

# %%
df[df["Identifying and solving problems as they arise"]>sol]
# Out:
# Empty DataFrame
# ...

# %%
sns.boxplot(df["Please rate your ability to work as a member of a team in the following domains:Communicating and listening to the ideas of others"]) # found some outliers
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Please rate your ability to work as a member of a team in the following domains:Communicating and listening to the ideas of others'>

# %%
# Choose the maximuim quantile to fill in the outliers


rating = df["Please rate your ability to work as a member of a team in the following domains:Communicating and listening to the ideas of others"].quantile(0.995)
rating
# Out:
# 5.0

# %%
df[df["Please rate your ability to work as a member of a team in the following domains:Communicating and listening to the ideas of others"]>rating]
# Out:
# Empty DataFrame
# ...

# %%
sns.boxplot(df["Completing assigned group tasks"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Completing assigned group tasks'>

# %%
# Choose the maximuim quantile to fill in the outliers

grp_tasks = df["Completing assigned group tasks"].quantile(0.995)
grp_tasks
# Out:
# 5.0

# %%
df[df["Completing assigned group tasks"]>grp_tasks]
# Out:
# Empty DataFrame
# ...

# %%
sns.boxplot(df["Valuing ideas and contributions of team members"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Valuing ideas and contributions of team members'>

# %%
# Choose the maximuim quantile to fill in the outliers


team = df["Valuing ideas and contributions of team members"].quantile(0.995)
team
# Out:
# 5.0

# %%
df[df["Valuing ideas and contributions of team members"]>team]
# Out:
# Empty DataFrame
# ...

# %%
sns.boxplot(df["Please rate your confidence in the following domains:Giving presentations"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Please rate your confidence in the following domains:Giving presentations'>

# %%
sns.boxplot(df["Leading groups"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Leading groups'>

# %%
sns.boxplot(df["Conducting meetings"])
# Out:
# C:\Users\Arulmani Padayachee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Conducting meetings'>

# %%
# Out:
#       Name  Squad Number Do you have any preferred language of communication?  \
# 0  Grayson           NaN  i prefer english but i am also able to communi...
# 1    Jonas           NaN                                            English
# 2    Ronan           NaN               English and Spanish are good for me.
# 3    Dulce           NaN                                            spanish
# 4   Evelyn           NaN                                            Spanish
#
#   What Group Virtual Internship Program are you interested in registering for  \
# 0                  Product Marketing,Product Growth
# 1   Product Marketing,Product Growth ,Product Design
# 2                                     Product Design
# 3                                     Product Design
# 4                                  Product Marketing
#
#     Age                     City Country 1    Country    Region  \
# 0  23.0       bordj bou arreridj       NaN    Algeria      MENA
# ...

# %%
# check for duplicate values

df.duplicated()

# there are no duplicates present in the dataset
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1183    False
# 1184    False
# 1185    False
# 1186    False
# 1187    False
# Length: 1188, dtype: bool

# %%
df.to_csv("clean csv file test")
